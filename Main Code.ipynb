# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy import stats
#from collections import Counter
# !pip install ucimlrepo

# %% [markdown]
# NEED TO IMPORT data_setup.py
